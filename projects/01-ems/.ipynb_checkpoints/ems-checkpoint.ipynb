# %% [markdown]
# ## Idea
#
# Ambulance response times in NYC: The black spots to have an emergency in NYC
#
# ### Questions
#
# Which are the worst communicated areas to have an emergency?
# Which is the Ambulance Response Times for different areas in NYC?
# How long does it take for an ambulance to arrive to the emergency scene?
# Which are the average response times for eack kind of emergencies?
#
# ### Context
#
# I am going to analise the [Emergency Medical Services (EMS)]() Incident Dispatch Data.
#
# https://data.cityofnewyork.us/Public-Safety/EMS-Incident-Dispatch-Data/76xm-jjuj
#
#
# The EMS Incident Dispatch Data file contains data that is generated by the EMS Computer Aided Dispatch System. The data spans from the time the incident is created in the system to the time the incident is closed in the system. It covers information about the incident as it relates to the assignment of resources and the Fire Department’s response to the emergency. To protect personal identifying information in accordance with the Health Insurance Portability and Accountability Act (HIPAA), specific locations of incidents are not included and have been aggregated to a higher level of detail.
#
# The data can be donwloaded in .csv or accesed via API:
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/66ae-7zpy
#
# As there are ~7M of rows and 32 columns, I am going to pull the data via API.
#
# #### Resources:
# * SODA: https://dev.socrata.com/
# * Paging through Data: https://dev.socrata.com/docs/paging.html#2.1
# * Authentication: https://dev.socrata.com/docs/authentication.html

# %% [markdown]
# ### First approach with requests

# %%
import requests
response = requests.get('https://data.cityofnewyork.us/resource/66ae-7zpy.json')
data = response.json()
print(data[0])
# Out:
# {'borough': 'BRONX', 'cad_incident_id': '130010001', 'citycouncildistrict': '18', 'communitydistrict': '209', 'communityschooldistrict': '12', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '101', 'final_call_type': 'RESPIR', 'final_severity_level_code': '4', 'first_activation_datetime': '2013-01-01T00:01:51.000', 'first_assignment_datetime': '2013-01-01T00:01:45.000', 'first_hosp_arrival_datetime': '2013-01-01T00:38:15.000', 'first_on_scene_datetime': '2013-01-01T00:13:21.000', 'first_to_hosp_datetime': '2013-01-01T00:28:49.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T01:04:56.000', 'incident_datetime': '2013-01-01T00:00:04.000', 'incident_dispatch_area': 'B3', 'incident_disposition_code': '82', 'incident_response_seconds_qy': '797', 'incident_travel_tm_seconds_qy': '696', 'initial_call_type': 'RESPIR', 'initial_severity_level_code': '4', 'policeprecinct': '43', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '10472'}

# %% [markdown]
# ### For loop with the first 10 results

# %%
datajson = []

for row in data[:10]:
    
    rowdict = {}
    
    rowdict['borough'] = row['borough']
    rowdict['cad_incident_id'] = row['cad_incident_id']
    rowdict['citycouncildistrict'] = row['citycouncildistrict']
    rowdict['communitydistrict'] = row['communitydistrict']
    rowdict['communityschooldistrict'] = row['communityschooldistrict']
    rowdict['congressionaldistrict'] = row['congressionaldistrict']
    rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
    rowdict['final_call_type'] = row['final_call_type']
    rowdict['final_severity_level_code'] = row['final_severity_level_code']
    rowdict['first_activation_datetim'] = row['first_activation_datetime']
    rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
    rowdict['final_severity_level_code'] = row['final_severity_level_code']
    rowdict['first_activation_datetime'] = row['first_activation_datetime']
    rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
    #rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
    rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
    #rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
    rowdict['held_indicator'] = row['held_indicator']
    rowdict['incident_close_datetime'] = row['incident_close_datetime']
    rowdict['incident_datetime'] = row['incident_datetime']
    rowdict['incident_dispatch_area'] = row['incident_dispatch_area']
    rowdict['incident_disposition_code'] = row['incident_disposition_code']
    rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
    rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
    rowdict['initial_call_type'] = row['initial_call_type']
    rowdict['initial_severity_level_code'] = row['initial_severity_level_code']
    rowdict['policeprecinct'] = row['policeprecinct']
    rowdict['reopen_indicator'] = row['reopen_indicator']
    rowdict['special_event_indicator'] = row['special_event_indicator']
    rowdict['standby_indicator'] = row['standby_indicator']
    rowdict['transfer_indicator'] = row['transfer_indicator']
    rowdict['valid_dispatch_rspns_time_indc'] = row['valid_dispatch_rspns_time_indc']
    rowdict['valid_incident_rspns_time_indc'] = row['valid_incident_rspns_time_indc']
    rowdict['zipcode'] = row['zipcode']

    datajson.append(rowdict)
    
print(datajson)
# Out:
# [{'borough': 'BRONX', 'cad_incident_id': '130010001', 'citycouncildistrict': '18', 'communitydistrict': '209', 'communityschooldistrict': '12', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '101', 'final_call_type': 'RESPIR', 'final_severity_level_code': '4', 'first_activation_datetim': '2013-01-01T00:01:51.000', 'first_assignment_datetime': '2013-01-01T00:01:45.000', 'first_activation_datetime': '2013-01-01T00:01:51.000', 'first_on_scene_datetime': '2013-01-01T00:13:21.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T01:04:56.000', 'incident_datetime': '2013-01-01T00:00:04.000', 'incident_dispatch_area': 'B3', 'incident_disposition_code': '82', 'incident_response_seconds_qy': '797', 'incident_travel_tm_seconds_qy': '696', 'initial_call_type': 'RESPIR', 'initial_severity_level_code': '4', 'policeprecinct': '43', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '10472'}, {'borough': 'BRONX', 'cad_incident_id': '130010002', 'citycouncildistrict': '8', 'communitydistrict': '201', 'communityschooldistrict': '7', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '59', 'final_call_type': 'CARD', 'final_severity_level_code': '3', 'first_activation_datetim': '2013-01-01T00:02:08.000', 'first_assignment_datetime': '2013-01-01T00:01:18.000', 'first_activation_datetime': '2013-01-01T00:02:08.000', 'first_on_scene_datetime': '2013-01-01T00:14:30.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T00:55:34.000', 'incident_datetime': '2013-01-01T00:00:19.000', 'incident_dispatch_area': 'B1', 'incident_disposition_code': '93', 'incident_response_seconds_qy': '851', 'incident_travel_tm_seconds_qy': '792', 'initial_call_type': 'CARD', 'initial_severity_level_code': '3', 'policeprecinct': '40', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '10454'}, {'borough': 'QUEENS', 'cad_incident_id': '130010004', 'citycouncildistrict': '29', 'communitydistrict': '409', 'communityschooldistrict': '27', 'congressionaldistrict': '5', 'dispatch_response_seconds_qy': '29', 'final_call_type': 'ARREST', 'final_severity_level_code': '1', 'first_activation_datetim': '2013-01-01T00:01:58.000', 'first_assignment_datetime': '2013-01-01T00:01:33.000', 'first_activation_datetime': '2013-01-01T00:01:58.000', 'first_on_scene_datetime': '2013-01-01T00:08:13.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T00:38:05.000', 'incident_datetime': '2013-01-01T00:01:04.000', 'incident_dispatch_area': 'Q3', 'incident_disposition_code': '83', 'incident_response_seconds_qy': '429', 'incident_travel_tm_seconds_qy': '400', 'initial_call_type': 'ARREST', 'initial_severity_level_code': '1', 'policeprecinct': '102', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '11418'}, {'borough': 'BRONX', 'cad_incident_id': '130010005', 'citycouncildistrict': '14', 'communitydistrict': '205', 'communityschooldistrict': '10', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '56', 'final_call_type': 'SICK', 'final_severity_level_code': '6', 'first_activation_datetim': '2013-01-01T00:02:55.000', 'first_assignment_datetime': '2013-01-01T00:02:12.000', 'first_activation_datetime': '2013-01-01T00:02:55.000', 'first_on_scene_datetime': '2013-01-01T00:15:04.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T01:20:28.000', 'incident_datetime': '2013-01-01T00:01:16.000', 'incident_dispatch_area': 'B2', 'incident_disposition_code': '82', 'incident_response_seconds_qy': '828', 'incident_travel_tm_seconds_qy': '772', 'initial_call_type': 'SICK', 'initial ...

# %%
datajson = []

for row in data[:10]:
    
    rowdict = {}
    
    try:
        rowdict['borough'] = row['borough']
        rowdict['cad_incident_id'] = row['cad_incident_id']
        rowdict['citycouncildistrict'] = row['citycouncildistrict']
        rowdict['communitydistrict'] = row['communitydistrict']
        rowdict['communityschooldistrict'] = row['communityschooldistrict']
        rowdict['congressionaldistrict'] = row['congressionaldistrict']
        rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
        rowdict['final_call_type'] = row['final_call_type']
        rowdict['final_severity_level_code'] = row['final_severity_level_code']
        rowdict['first_activation_datetim'] = row['first_activation_datetime']
        rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        rowdict['final_severity_level_code'] = row['final_severity_level_code']
        rowdict['first_activation_datetime'] = row['first_activation_datetime']
        rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
        rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
        rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
        rowdict['held_indicator'] = row['held_indicator']
        rowdict['incident_close_datetime'] = row['incident_close_datetime']
        rowdict['incident_datetime'] = row['incident_datetime']
        rowdict['incident_dispatch_area'] = row['incident_dispatch_area']
        rowdict['incident_disposition_code'] = row['incident_disposition_code']
        rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
        rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
        rowdict['initial_call_type'] = row['initial_call_type']
        rowdict['initial_severity_level_code'] = row['initial_severity_level_code']
        rowdict['policeprecinct'] = row['policeprecinct']
        rowdict['reopen_indicator'] = row['reopen_indicator']
        rowdict['special_event_indicator'] = row['special_event_indicator']
        rowdict['standby_indicator'] = row['standby_indicator']
        rowdict['transfer_indicator'] = row['transfer_indicator']
        rowdict['valid_dispatch_rspns_time_indc'] = row['valid_dispatch_rspns_time_indc']
        rowdict['valid_incident_rspns_time_indc'] = row['valid_incident_rspns_time_indc']
        rowdict['zipcode'] = row['zipcode']
        
    except:
        
        continue

    datajson.append(rowdict)
    
print(datajson)
# Out:
# [{'borough': 'BRONX', 'cad_incident_id': '130010001', 'citycouncildistrict': '18', 'communitydistrict': '209', 'communityschooldistrict': '12', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '101', 'final_call_type': 'RESPIR', 'final_severity_level_code': '4', 'first_activation_datetim': '2013-01-01T00:01:51.000', 'first_assignment_datetime': '2013-01-01T00:01:45.000', 'first_activation_datetime': '2013-01-01T00:01:51.000', 'first_hosp_arrival_datetime': '2013-01-01T00:38:15.000', 'first_on_scene_datetime': '2013-01-01T00:13:21.000', 'first_to_hosp_datetime': '2013-01-01T00:28:49.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T01:04:56.000', 'incident_datetime': '2013-01-01T00:00:04.000', 'incident_dispatch_area': 'B3', 'incident_disposition_code': '82', 'incident_response_seconds_qy': '797', 'incident_travel_tm_seconds_qy': '696', 'initial_call_type': 'RESPIR', 'initial_severity_level_code': '4', 'policeprecinct': '43', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '10472'}, {'borough': 'BRONX', 'cad_incident_id': '130010005', 'citycouncildistrict': '14', 'communitydistrict': '205', 'communityschooldistrict': '10', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '56', 'final_call_type': 'SICK', 'final_severity_level_code': '6', 'first_activation_datetim': '2013-01-01T00:02:55.000', 'first_assignment_datetime': '2013-01-01T00:02:12.000', 'first_activation_datetime': '2013-01-01T00:02:55.000', 'first_hosp_arrival_datetime': '2013-01-01T00:53:02.000', 'first_on_scene_datetime': '2013-01-01T00:15:04.000', 'first_to_hosp_datetime': '2013-01-01T00:34:54.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T01:20:28.000', 'incident_datetime': '2013-01-01T00:01:16.000', 'incident_dispatch_area': 'B2', 'incident_disposition_code': '82', 'incident_response_seconds_qy': '828', 'incident_travel_tm_seconds_qy': '772', 'initial_call_type': 'SICK', 'initial_severity_level_code': '6', 'policeprecinct': '46', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '10453'}, {'borough': 'BRONX', 'cad_incident_id': '130010006', 'citycouncildistrict': '15', 'communitydistrict': '206', 'communityschooldistrict': '10', 'congressionaldistrict': '15', 'dispatch_response_seconds_qy': '32', 'final_call_type': 'INJURY', 'final_severity_level_code': '5', 'first_activation_datetim': '2013-01-01T00:02:55.000', 'first_assignment_datetime': '2013-01-01T00:01:58.000', 'first_activation_datetime': '2013-01-01T00:02:55.000', 'first_hosp_arrival_datetime': '2013-01-01T00:31:13.000', 'first_on_scene_datetime': '2013-01-01T00:15:42.000', 'first_to_hosp_datetime': '2013-01-01T00:27:42.000', 'held_indicator': 'N', 'incident_close_datetime': '2013-01-01T00:53:12.000', 'incident_datetime': '2013-01-01T00:01:26.000', 'incident_dispatch_area': 'B2', 'incident_disposition_code': '82', 'incident_response_seconds_qy': '856', 'incident_travel_tm_seconds_qy': '824', 'initial_call_type': 'INJURY', 'initial_severity_level_code': '5', 'policeprecinct': '48', 'reopen_indicator': 'N', 'special_event_indicator': 'N', 'standby_indicator': 'N', 'transfer_indicator': 'N', 'valid_dispatch_rspns_time_indc': 'Y', 'valid_incident_rspns_time_indc': 'Y', 'zipcode': '10457'}, {'borough': 'RICHMOND / STATEN ISLAND', 'cad_incident_id': '130010009', 'citycouncildistrict': '49', 'communitydistrict': '501', 'communityschooldistrict': '31', 'congressionaldistrict': '11', 'dispatch_response_seconds_qy': '12', 'final_call_type': 'DRUG', 'final_severity_level_code': '4', 'first_activation_datetim': '2013-01-01T00:02:36.000', 'first_assignment_datetime': '2013-01-01T00:02:23.000', 'first_activation_datetime': '2013-01-01T00:02:36.000', 'first_ho ...

# %%
### Filters to apply later

# %%
datajson2 = []

for row in data:
    
    rowdict = {}
    
    try:
        
        if row['dispatch_response_seconds_qy'] > 1:
            
            rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']

        rowdict['borough'] = row['borough']
        #rowdict['cad_incident_id'] = row['cad_incident_id']
        #rowdict['citycouncildistrict'] = row['citycouncildistrict']
        #rowdict['communitydistrict'] = row['communitydistrict']
        #rowdict['communityschooldistrict'] = row['communityschooldistrict']
        #rowdict['congressionaldistrict'] = row['congressionaldistrict']
        rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
        #rowdict['final_call_type'] = row['final_call_type']
        #rowdict['final_severity_level_code'] = row['final_severity_level_code']
        #rowdict['first_activation_datetim'] = row['first_activation_datetime']
        #rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        #rowdict['final_severity_level_code'] = row['final_severity_level_code']
        #rowdict['first_activation_datetime'] = row['first_activation_datetime']
        #rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        #rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
        #rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
        #rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
        #rowdict['held_indicator'] = row['held_indicator']
        #rowdict['incident_close_datetime'] = row['incident_close_datetime']
        #rowdict['incident_datetime'] = row['incident_datetime']
        #rowdict['incident_dispatch_area'] = row['incident_dispatch_area']
        #rowdict['incident_disposition_code'] = row['incident_disposition_code']
        rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
        rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
        #rowdict['initial_call_type'] = row['initial_call_type']
        #rowdict['initial_severity_level_code'] = row['initial_severity_level_code']
        #rowdict['policeprecinct'] = row['policeprecinct']
        #rowdict['reopen_indicator'] = row['reopen_indicator']
        #rowdict['special_event_indicator'] = row['special_event_indicator']
        #rowdict['standby_indicator'] = row['standby_indicator']
        #rowdict['transfer_indicator'] = row['transfer_indicator']
        #rowdict['valid_dispatch_rspns_time_indc'] = row['valid_dispatch_rspns_time_indc']
        #rowdict['valid_incident_rspns_time_indc'] = row['valid_incident_rspns_time_indc']
        rowdict['zipcode'] = row['zipcode']
        
    except:
        
        continue

    datajson2.append(rowdict)
    
print(datajson2)
# Out:
# []

# %%
datajson2 = []

for row in data:
    
    rowdict = {}
    
    try:

        rowdict['borough'] = row['borough']
        #rowdict['cad_incident_id'] = row['cad_incident_id']
        #rowdict['citycouncildistrict'] = row['citycouncildistrict']
        #rowdict['communitydistrict'] = row['communitydistrict']
        #rowdict['communityschooldistrict'] = row['communityschooldistrict']
        #rowdict['congressionaldistrict'] = row['congressionaldistrict']
        rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
        #rowdict['final_call_type'] = row['final_call_type']
        #rowdict['final_severity_level_code'] = row['final_severity_level_code']
        #rowdict['first_activation_datetim'] = row['first_activation_datetime']
        #rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        #rowdict['final_severity_level_code'] = row['final_severity_level_code']
        #rowdict['first_activation_datetime'] = row['first_activation_datetime']
        #rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        #rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
        #rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
        #rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
        #rowdict['held_indicator'] = row['held_indicator']
        #rowdict['incident_close_datetime'] = row['incident_close_datetime']
        #rowdict['incident_datetime'] = row['incident_datetime']
        #rowdict['incident_dispatch_area'] = row['incident_dispatch_area']
        #rowdict['incident_disposition_code'] = row['incident_disposition_code']
        rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
        rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
        #rowdict['initial_call_type'] = row['initial_call_type']
        #rowdict['initial_severity_level_code'] = row['initial_severity_level_code']
        #rowdict['policeprecinct'] = row['policeprecinct']
        #rowdict['reopen_indicator'] = row['reopen_indicator']
        #rowdict['special_event_indicator'] = row['special_event_indicator']
        #rowdict['standby_indicator'] = row['standby_indicator']
        #rowdict['transfer_indicator'] = row['transfer_indicator']
        #rowdict['valid_dispatch_rspns_time_indc'] = row['valid_dispatch_rspns_time_indc']
        #rowdict['valid_incident_rspns_time_indc'] = row['valid_incident_rspns_time_indc']
        rowdict['zipcode'] = row['zipcode']
        
    except:
        
        continue

    datajson2.append(rowdict)
    
print(datajson2)
# Out:
# [{'borough': 'BRONX', 'dispatch_response_seconds_qy': '101', 'incident_response_seconds_qy': '797', 'incident_travel_tm_seconds_qy': '696', 'zipcode': '10472'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '59', 'incident_response_seconds_qy': '851', 'incident_travel_tm_seconds_qy': '792', 'zipcode': '10454'}, {'borough': 'QUEENS', 'dispatch_response_seconds_qy': '29', 'incident_response_seconds_qy': '429', 'incident_travel_tm_seconds_qy': '400', 'zipcode': '11418'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '56', 'incident_response_seconds_qy': '828', 'incident_travel_tm_seconds_qy': '772', 'zipcode': '10453'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '32', 'incident_response_seconds_qy': '856', 'incident_travel_tm_seconds_qy': '824', 'zipcode': '10457'}, {'borough': 'MANHATTAN', 'dispatch_response_seconds_qy': '16', 'incident_response_seconds_qy': '244', 'incident_travel_tm_seconds_qy': '228', 'zipcode': '10017'}, {'borough': 'RICHMOND / STATEN ISLAND', 'dispatch_response_seconds_qy': '13', 'incident_response_seconds_qy': '375', 'incident_travel_tm_seconds_qy': '362', 'zipcode': '10306'}, {'borough': 'RICHMOND / STATEN ISLAND', 'dispatch_response_seconds_qy': '12', 'incident_response_seconds_qy': '428', 'incident_travel_tm_seconds_qy': '416', 'zipcode': '10301'}, {'borough': 'MANHATTAN', 'dispatch_response_seconds_qy': '19', 'incident_response_seconds_qy': '323', 'incident_travel_tm_seconds_qy': '304', 'zipcode': '10013'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '25', 'incident_response_seconds_qy': '172', 'incident_travel_tm_seconds_qy': '147', 'zipcode': '10467'}, {'borough': 'MANHATTAN', 'dispatch_response_seconds_qy': '221', 'incident_response_seconds_qy': '444', 'incident_travel_tm_seconds_qy': '223', 'zipcode': '10010'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '12', 'incident_response_seconds_qy': '297', 'incident_travel_tm_seconds_qy': '285', 'zipcode': '11203'}, {'borough': 'MANHATTAN', 'dispatch_response_seconds_qy': '1171', 'incident_response_seconds_qy': '1537', 'incident_travel_tm_seconds_qy': '366', 'zipcode': '10001'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '34', 'incident_response_seconds_qy': '318', 'incident_travel_tm_seconds_qy': '284', 'zipcode': '11206'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '24', 'incident_response_seconds_qy': '389', 'incident_travel_tm_seconds_qy': '365', 'zipcode': '10462'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '23', 'incident_response_seconds_qy': '660', 'incident_travel_tm_seconds_qy': '637', 'zipcode': '10461'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '75', 'incident_response_seconds_qy': '393', 'incident_travel_tm_seconds_qy': '318', 'zipcode': '11203'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '16', 'incident_response_seconds_qy': '443', 'incident_travel_tm_seconds_qy': '427', 'zipcode': '10458'}, {'borough': 'BRONX', 'dispatch_response_seconds_qy': '12', 'incident_response_seconds_qy': '534', 'incident_travel_tm_seconds_qy': '522', 'zipcode': '10472'}, {'borough': 'MANHATTAN', 'dispatch_response_seconds_qy': '178', 'incident_response_seconds_qy': '562', 'incident_travel_tm_seconds_qy': '384', 'zipcode': '10036'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '31', 'incident_response_seconds_qy': '357', 'incident_travel_tm_seconds_qy': '326', 'zipcode': '11233'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '20', 'incident_response_seconds_qy': '183', 'incident_travel_tm_seconds_qy': '163', 'zipcode': '11220'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '18', 'incident_response_seconds_qy': '308', 'incident_travel_tm_seconds_qy': '290', 'zipcode': '11217'}, {'borough': 'MANHATTAN', 'dispatch_response_seconds_qy': '30', 'incident_response_seconds_qy': '232', 'incident_travel_tm_seconds_qy': '202', 'zipcode': '10033'}, {'borough': 'BROOKLYN', 'dispatch_response_seconds_qy': '26', 'incident_response_seconds_qy': '2 ...

# %% [markdown]
# ### Socrata

# %%
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
    'axes.titlesize': 'x-large',
    'axes.grid': True,
    'grid.color': '#131313',
    'axes.axisbelow': True,
    'font.serif': 'Arial',
    'figure.facecolor': '#F6F6EE',
    'figure.titleweight' : 'bold',
    'figure.titlesize' : 'large',
    'axes.grid': False,
    'patch.edgecolor': '#131313',
    'text.color': '#131313',
    'axes.facecolor': '#F6F6EE',
    'axes.prop_cycle': cycler('color', ['#384A77', '#D0112B', '#FDCF44', '#131313', '#ffffff', '#156261', '#D6D6D6']),
    'axes.spines.left' : True,
    'axes.spines.right' : False,
    'axes.spines.top' : False,
    'axes.spines.bottom' : False,
    'xtick.top' : False,
    'xtick.bottom' : False,
    'ytick.left' : False,
    'axes.titlepad' : 50.0,
    'legend.frameon' : False,
    'legend.loc' : 'best',
    'legend.columnspacing' : 0.0,
    'ytick.major.pad' : 2.5
})

# %% [markdown]
# ### RESPIR

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  "qujCY0ItA3K3bvjptIYdt6Kg1",
                  username="adrianblanco@ucm.es",
                  password="Conocido_91")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("66ae-7zpy", final_call_type="RESPIR", limit=200000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.shape
# Out:
# (113578, 32)

# %%
results[0]
# Out:
# {'borough': 'BRONX',
#  'cad_incident_id': '130010001',
#  'citycouncildistrict': '18',
#  'communitydistrict': '209',
#  'communityschooldistrict': '12',
#  'congressionaldistrict': '15',
#  'dispatch_response_seconds_qy': '101',
#  'final_call_type': 'RESPIR',
#  'final_severity_level_code': '4',
#  'first_activation_datetime': '2013-01-01T00:01:51.000',
#  'first_assignment_datetime': '2013-01-01T00:01:45.000',
#  'first_hosp_arrival_datetime': '2013-01-01T00:38:15.000',
#  'first_on_scene_datetime': '2013-01-01T00:13:21.000',
#  'first_to_hosp_datetime': '2013-01-01T00:28:49.000',
#  'held_indicator': 'N',
#  'incident_close_datetime': '2013-01-01T01:04:56.000',
#  'incident_datetime': '2013-01-01T00:00:04.000',
#  'incident_dispatch_area': 'B3',
#  'incident_disposition_code': '82',
#  'incident_response_seconds_qy': '797',
#  'incident_travel_tm_seconds_qy': '696',
#  'initial_call_type': 'RESPIR',
#  'initial_severity_level_code': '4',
#  'policeprecinct': '43',
#  'reopen_indicator': 'N',
#  'special_event_indicator': 'N',
#  'standby_indicator': 'N',
#  'transfer_indicator': 'N',
#  'valid_dispatch_rspns_time_indc': 'Y',
#  'valid_incident_rspns_time_indc': 'Y',
#  'zipcode': '10472'}

# %%
respir_list = []

for row in results:
    
    rowdict = {}
    
    try:
        
        rowdict['zipcode'] = row['zipcode']
        rowdict['borough'] = row['borough']
        rowdict['incident_datetime'] = row['incident_datetime']
        rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
        rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
        rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
        rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
        rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
        rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
        rowdict['incident_disposition_code'] = row['incident_disposition_code']
        rowdict['final_call_type'] = row['final_call_type']
        
    #rowdict[''] = row['']

    except:
        
        continue
        
    respir_list.append(rowdict)
    
respir_df = pd.DataFrame.from_records(respir_list)
respir_df.head()
# Out:
#      borough dispatch_response_seconds_qy final_call_type  \
# 0      BRONX                          101          RESPIR
# 1  MANHATTAN                          221          RESPIR
# 2   BROOKLYN                          152          RESPIR
# 3   BROOKLYN                           39          RESPIR
# 4   BROOKLYN                           18          RESPIR
#
#   first_assignment_datetime first_hosp_arrival_datetime  \
# 0   2013-01-01T00:01:45.000     2013-01-01T00:38:15.000
# 1   2013-01-01T00:07:10.000     2013-01-01T00:34:14.000
# 2   2013-01-01T00:24:07.000     2013-01-01T01:08:07.000
# 3   2013-01-01T00:25:57.000     2013-01-01T00:47:45.000
# 4   2013-01-01T00:40:39.000     2013-01-01T01:13:45.000
#
#    first_on_scene_datetime   first_to_hosp_datetime        incident_datetime  \
# 0  2013-01-01T00:13:21.000  2013-01-01T00:28:49.000  2013-01-01T00:00:04.000
# 1  2013-01-01T00:10:53.000  2013-01-01T00:28:36.000  2013-01-01T00:03:29.000
# 2  2013-01-01T00:33:18.000  2013-01-01T01:04:06.000  2013-01-01T00:21:35.000
# 3  2013-01-01T00:30:00.000  2013-01-01T00:42:15.000  2013-01-01T00:25:18.000
# 4  2013-01-01T00:48:34.000  2013-01-01T00:58:51.000  2013-01-01T00:40:21.000
#
#   incident_disposition_code incident_response_seconds_qy  \
# 0                        82                          797
# 1                        82                          444
# 2                        82                          703
# 3                        82                          282
# 4                        82                          493
#
#   incident_travel_tm_seconds_qy zipcode
# 0                           696   10472
# 1                           223   10010
# 2                           551   11226
# 3                           243   11225
# 4                           475   11249

# %%
respir_df['incident_response_min_qy'] = round((respir_df['incident_response_seconds_qy'].astype(int))/60,2)
respir_df
# Out:
#                         borough dispatch_response_seconds_qy final_call_type  \
# 0                         BRONX                          101          RESPIR
# 1                     MANHATTAN                          221          RESPIR
# 2                      BROOKLYN                          152          RESPIR
# 3                      BROOKLYN                           39          RESPIR
# 4                      BROOKLYN                           18          RESPIR
# 5                         BRONX                           57          RESPIR
# 6                      BROOKLYN                           11          RESPIR
# 7                      BROOKLYN                           13          RESPIR
# 8      RICHMOND / STATEN ISLAND                           12          RESPIR
# 9                      BROOKLYN                           34          RESPIR
# 10                    MANHATTAN                          141          RESPIR
# 11                        BRONX                           41          RESPIR
# 12                        BRONX                          538          RESPIR
# 13                        BRONX                          249          RESPIR
# 14                        BRONX                           71          RESPIR
# 15                     BROOKLYN                           42          RESPIR
# 16                    MANHATTAN                          492          RESPIR
# 17                     BROOKLYN                           23          RESPIR
# 18                     BROOKLYN                           13          RESPIR
# 19                        BRONX                           43          RESPIR
# 20                     BROOKLYN                           71          RESPIR
# 21                        BRONX                          201          RESPIR
# 22                     BROOKLYN                           30          RESPIR
# 23                     BROOKLYN                           17          RESPIR
# 24                     BROOKLYN                           36          RESPIR
# 25                       QUEENS                           34          RESPIR
# 26                        BRONX                           26          RESPIR
# 27                    MANHATTAN                           12          RESPIR
# 28                        BRONX                           22          RESPIR
# 29                       QUEENS                           18          RESPIR
# ...                         ...                          ...             ...
# 87997                     BRONX                           15          RESPIR
# 87998                 MANHATTAN                           67          RESPIR
# 87999                 MANHATTAN                           21          RESPIR
# 88000                 MANHATTAN                           29          RESPIR
# 88001                  BROOKLYN                           19          RESPIR
# 88002                     BRONX                           51          RESPIR
# 88003                    QUEENS                           30          RESPIR
# 88004                 MANHATTAN                           26          RESPIR
# 88005                  BROOKLYN                            9          RESPIR
# 88006                  BROOKLYN                           27          RESPIR
# 88007                 MANHATTAN                           24          RESPIR
# 88008                 MANHATTAN                           33          RESPIR
# 88009                     BRONX                           25          RESPIR
# 88010                     BRONX                           13          RESPIR
# 88011                 MANHATTAN                           24          RESPIR
# 88012                     BRONX                           20          RESPIR
# 88013                  BROOKLYN                            7          RESPIR
# 88014                 MANHATTAN                           12          RESPIR
# 88015                    QUEENS                           70          RESPIR
# 88016                 MANHATTAN                           12          RESPIR
# 88017                     BRONX                           22          RESPIR
# 88018                     BRONX                            9          RESPIR
# 88019                     BRONX                           10          RESPIR
# 88020                  BROOKLYN                          239          RESPIR
# 88021                     BRONX                           31          RESPIR
# 88022  RICHMOND / STATEN ISLAND                            5          RESPIR
# 88023                 MANHATTAN                           64          RESPIR
# 88024                  BROOKLYN                           37          RESPIR
# 88025                     BRONX                          108          RESPIR
# 88026                  BROOKLYN                          111          RESPIR
#
#       first_assignment_datetime first_hosp_arrival_datetime  \
# 0       2013-01-01T00:01:45.000     2013-01-01T00:38:15.000
# 1       2013-01-01T00:07:10.000     2013-01-01T00:34:14.000
# 2       2013-01-01T00:24:07.000     2013-01-01T01:08:07.000
# 3       2013-01-01T00:25:57.000     2013-01-01T00:47:45.000
# 4       2013-01-01T00:40:39.000     2013-01-01T01:13:45.000
# 5       2013-01-01T01:18:26.000     2013-01-01T01:47:36.000
# 6       2013-01-01T01:21:58.000     2013-01-01T02:02:56.000
# 7       2013-01-01T01:24:41.000     2013-01-01T01:56:40.000
# 8       2013-01-01T01:28:35.000     2013-01-01T01:59:00.000
# 9       2013-01-01T01:30:40.000     2013-01-01T01:58:57.000
# 10      2013-01-01T01:38:47.000     2013-01-01T02:00:13.000
# 11      2013-01-01T02:32:15.000     2013-01-01T03:08:49.000
# 12      2013-01-01T02:49:09.000     2013-01-01T03:52:19.000
# 13      2013-01-01T02:55:20.000     2013-01-01T03:50:34.000
# 14      2013-01-01T03:46:46.000     2013-01-01T04:20:47.000
# 15      2013-01-01T04:22:52.000     2013-01-01T05:05:22.000
# 16      2013-01-01T05:43:40.000     2013-01-01T06:11:55.000
# 17      2013-01-01T06:14:08.000     2013-01-01T06:49:17.000
# 18      2013-01-01T06:22:25.000     2013-01-01T07:05:47.000
# 19      2013-01-01T06:48:35.000     2013-01-01T07:30:16.000
# 20      2013-01-01T07:26:49.000     2013-01-01T08:08:32.000
# 21      2013-01-01T07:37:57.000     2013-01-01T08:19:28.000
# 22      2013-01-01T07:54:14.000     2013-01-01T08:31:18.000
# 23      2013-01-01T07:54:34.000     2013-01-01T08:35:15.000
# 24      2013-01-01T08:11:18.000     2013-01-01T08:33:42.000
# 25      2013-01-01T08:20:36.000     2013-01-01T08:45:24.000
# 26      2013-01-01T08:42:03.000     2013-01-01T09:02:28.000
# 27      2013-01-01T08:43:37.000     2013-01-01T09:08:59.000
# 28      2013-01-01T09:15:26.000     2013-01-01T09:33:04.000
# 29      2013-01-01T09:21:06.000     2013-01-01T09:53:59.000
# ...                         ...                         ...
# 87997   2016-08-13T02:33:57.000     2016-08-13T03:17:37.000
# 87998   2017-07-07T14:18:43.000     2017-07-07T14:45:22.000
# 87999   2017-05-30T23:21:48.000     2017-05-30T23:47:18.000
# 88000   2016-12-13T19:21:35.000     2016-12-13T20:07:19.000
# 88001   2016-10-11T17:42:11.000     2016-10-11T18:00:25.000
# 88002   2016-10-12T01:03:27.000     2016-10-12T01:37:15.000
# 88003   2016-08-21T01:12:05.000     2016-08-21T02:02:11.000
# 88004   2017-08-23T14:50:04.000     2017-08-23T15:23:27.000
# 88005   2017-08-13T06:30:37.000     2017-08-13T07:01:27.000
# 88006   2017-03-23T11:09:13.000     2017-03-23T12:01:42.000
# 88007   2016-12-18T15:41:49.000     2016-12-18T16:13:14.000
# 88008   2017-06-19T11:52:24.000     2017-06-19T12:49:02.000
# 88009   2017-09-30T12:08:02.000     2017-09-30T12:43:34.000
# 88010   2017-02-06T09:59:20.000     2017-02-06T11:07:02.000
# 88011   2016-07-12T12:46:30.000     2016-07-12T13:36:11.000
# 88012   2017-10-26T12:32:33.000     2017-10-26T13:10:08.000
# 88013   2017-04-01T17:07:21.000     2017-04-01T17:54:40.000
# 88014   2017-06-09T16:26:56.000     2017-06-09T17:15:24.000
# 88015   2016-08-18T18:34:02.000     2016-08-18T19:10:21.000
# 88016   2016-11-11T04:28:38.000     2016-11-11T04:48:06.000
# 88017   2017-08-08T09:39:13.000     2017-08-08T10:11:00.000
# 88018   2017-08-25T11:30:04.000     2017-08-25T12:13:29.000
# 88019   2017-02-03T01:23:41.000     2017-02-03T02:00:03.000
# 88020   2016-07-26T21:37:27.000     2016-07-26T22:18:21.000
# 88021   2016-10-07T08:53:54.000     2016-10-07T09:51:58.000
# 88022   2017-07-12T12:10:46.000     2017-07-12T12:38:29.000
# 88023   2016-07-01T02:35:07.000     2016-07-01T03:07:05.000
# 88024   2016-08-24T04:10:52.000     2016-08-24T05:00:29.000
# 88025   2016-07-17T14:25:45.000     2016-07-17T15:22:03.000
# 88026   2017-07-15T21:10:14.000     2017-07-15T22:08:08.000
#
#        first_on_scene_datetime   first_to_hosp_datetime  \
# 0      2013-01-01T00:13:21.000  2013-01-01T00:28:49.000
# 1      2013-01-01T00:10:53.000  2013-01-01T00:28:36.000
# 2      2013-01-01T00:33:18.000  2013-01-01T01:04:06.000
# 3      2013-01-01T00:30:00.000  2013-01-01T00:42:15.000
# 4      2013-01-01T00:48:34.000  2013-01-01T00:58:51.000
# 5      2013-01-01T01:28:02.000  2013-01-01T01:38:52.000
# 6      2013-01-01T01:26:11.000  2013-01-01T01:48:04.000
# 7      2013-01-01T01:33:12.000  2013-01-01T01:49:31.000
# 8      2013-01-01T01:34:52.000  2013-01-01T01:49:12.000
# 9      2013-01-01T01:41:42.000  2013-01-01T01:46:03.000
# 10     2013-01-01T01:49:07.000  2013-01-01T01:55:42.000
# 11     2013-01-01T02:45:10.000  2013-01-01T03:01:05.000
# 12     2013-01-01T03:01:24.000  2013-01-01T03:28:04.000
# 13     2013-01-01T03:24:22.000  2013-01-01T03:38:04.000
# 14     2013-01-01T03:57:26.000  2013-01-01T04:10:52.000
# 15     2013-01-01T04:39:24.000  2013-01-01T04:58:51.000
# 16     2013-01-01T05:50:23.000  2013-01-01T06:06:25.000
# 17     2013-01-01T06:29:23.000  2013-01-01T06:46:33.000
# 18     2013-01-01T06:25:32.000  2013-01-01T06:56:47.000
# 19     2013-01-01T06:54:21.000  2013-01-01T07:22:34.000
# 20     2013-01-01T07:33:20.000  2013-01-01T07:51:21.000
# 21     2013-01-01T07:45:02.000  2013-01-01T08:14:59.000
# 22     2013-01-01T08:04:22.000  2013-01-01T08:20:33.000
# 23     2013-01-01T08:12:13.000  2013-01-01T08:27:17.000
# 24     2013-01-01T08:17:05.000  2013-01-01T08:27:15.000
# 25     2013-01-01T08:24:39.000  2013-01-01T08:37:25.000
# 26     2013-01-01T08:52:21.000  2013-01-01T08:59:45.000
# 27     2013-01-01T08:46:50.000  2013-01-01T09:08:55.000
# 28     2013-01-01T09:20:40.000  2013-01-01T09:28:12.000
# 29     2013-01-01T09:28:56.000  2013-01-01T09:48:05.000
# ...                        ...                      ...
# 87997  2016-08-13T02:48:56.000  2016-08-13T03:09:36.000
# 87998  2017-07-07T14:21:55.000  2017-07-07T14:28:57.000
# 87999  2017-05-30T23:25:35.000  2017-05-30T23:39:37.000
# 88000  2016-12-13T19:32:05.000  2016-12-13T19:56:56.000
# 88001  2016-10-11T17:45:19.000  2016-10-11T17:57:27.000
# 88002  2016-10-12T01:08:37.000  2016-10-12T01:30:13.000
# 88003  2016-08-21T01:21:05.000  2016-08-21T01:43:43.000
# 88004  2017-08-23T14:53:02.000  2017-08-23T15:16:55.000
# 88005  2017-08-13T06:37:30.000  2017-08-13T06:54:59.000
# 88006  2017-03-23T11:17:51.000  2017-03-23T11:41:52.000
# 88007  2016-12-18T15:50:34.000  2016-12-18T16:06:55.000
# 88008  2017-06-19T12:00:00.000  2017-06-19T12:16:36.000
# 88009  2017-09-30T12:17:28.000  2017-09-30T12:21:41.000
# 88010  2017-02-06T10:40:30.000  2017-02-06T10:58:10.000
# 88011  2016-07-12T12:59:05.000  2016-07-12T13:23:25.000
# 88012  2017-10-26T12:40:02.000  2017-10-26T13:04:37.000
# 88013  2017-04-01T17:14:37.000  2017-04-01T17:35:31.000
# 88014  2017-06-09T16:39:28.000  2017-06-09T17:09:42.000
# 88015  2016-08-18T18:41:25.000  2016-08-18T19:05:13.000
# 88016  2016-11-11T04:31:27.000  2016-11-11T04:40:03.000
# 88017  2017-08-08T09:44:49.000  2017-08-08T10:00:58.000
# 88018  2017-08-25T11:37:38.000  2017-08-25T11:59:43.000
# 88019  2017-02-03T01:30:23.000  2017-02-03T01:47:00.000
# 88020  2016-07-26T21:45:11.000  2016-07-26T22:05:09.000
# 88021  2016-10-07T09:16:34.000  2016-10-07T09:40:58.000
# 88022  2017-07-12T12:15:33.000  2017-07-12T12:32:12.000
# 88023  2016-07-01T02:41:20.000  2016-07-01T03:01:15.000
# 88024  2016-08-24T04:18:09.000  2016-08-24T04:41:34.000
# 88025  2016-07-17T14:41:25.000  2016-07-17T15:14:09.000
# 88026  2017-07-15T21:17:23.000  2017-07-15T21:43:25.000
#
#              incident_datetime incident_disposition_code  \
# 0      2013-01-01T00:00:04.000                        82
# 1      2013-01-01T00:03:29.000                        82
# 2      2013-01-01T00:21:35.000                        82
# 3      2013-01-01T00:25:18.000                        82
# 4      2013-01-01T00:40:21.000                        82
# 5      2013-01-01T01:17:29.000                        82
# 6      2013-01-01T01:21:47.000                        82
# 7      2013-01-01T01:24:28.000                        82
# 8      2013-01-01T01:28:23.000                        82
# 9      2013-01-01T01:30:06.000                        82
# 10     2013-01-01T01:36:26.000                        82
# 11     2013-01-01T02:31:34.000                        82
# 12     2013-01-01T02:40:11.000                        82
# 13     2013-01-01T02:51:11.000                        82
# 14     2013-01-01T03:45:35.000                        82
# 15     2013-01-01T04:22:10.000                        82
# 16     2013-01-01T05:35:28.000                        82
# 17     2013-01-01T06:13:45.000                        82
# 18     2013-01-01T06:22:12.000                        82
# 19     2013-01-01T06:47:52.000                        82
# 20     2013-01-01T07:25:38.000                        82
# 21     2013-01-01T07:34:36.000                        82
# 22     2013-01-01T07:53:44.000                        82
# 23     2013-01-01T07:54:17.000                        82
# 24     2013-01-01T08:10:42.000                        82
# 25     2013-01-01T08:20:02.000                        82
# 26     2013-01-01T08:41:37.000                        82
# 27     2013-01-01T08:43:25.000                        82
# 28     2013-01-01T09:15:04.000                        82
# 29     2013-01-01T09:20:48.000                        82
# ...                        ...                       ...
# 87997  2016-08-13T02:33:42.000                        82
# 87998  2017-07-07T14:17:36.000                        82
# 87999  2017-05-30T23:21:27.000                        82
# 88000  2016-12-13T19:21:06.000                        82
# 88001  2016-10-11T17:41:52.000                        82
# 88002  2016-10-12T01:02:36.000                        82
# 88003  2016-08-21T01:11:35.000                        82
# 88004  2017-08-23T14:49:38.000                        82
# 88005  2017-08-13T06:30:28.000                        82
# 88006  2017-03-23T11:08:46.000                        82
# 88007  2016-12-18T15:41:25.000                        82
# 88008  2017-06-19T11:51:51.000                        82
# 88009  2017-09-30T12:07:37.000                        82
# 88010  2017-02-06T09:59:07.000                        82
# 88011  2016-07-12T12:46:06.000                        82
# 88012  2017-10-26T12:32:13.000                        82
# 88013  2017-04-01T17:07:14.000                        82
# 88014  2017-06-09T16:26:44.000                        82
# 88015  2016-08-18T18:32:52.000                        82
# 88016  2016-11-11T04:28:26.000                        82
# 88017  2017-08-08T09:38:51.000                        82
# 88018  2017-08-25T11:29:55.000                        82
# 88019  2017-02-03T01:23:31.000                        82
# 88020  2016-07-26T21:33:28.000                        82
# 88021  2016-10-07T08:53:23.000                        82
# 88022  2017-07-12T12:10:41.000                        82
# 88023  2016-07-01T02:34:03.000                        82
# 88024  2016-08-24T04:10:15.000                        82
# 88025  2016-07-17T14:23:57.000                        82
# 88026  2017-07-15T21:08:23.000                        82
#
#       incident_response_seconds_qy incident_travel_tm_seconds_qy zipcode  \
# 0                              797                           696   10472
# 1                              444                           223   10010
# 2                              703                           551   11226
# 3                              282                           243   11225
# 4                              493                           475   11249
# 5                              633                           576   10456
# 6                              264                           253   11208
# 7                              524                           511   11207
# 8                              389                           377   10304
# 9                              696                           662   11208
# 10                             761                           620   10029
# 11                             816                           775   10458
# 12                            1273                           735   10455
# 13                            1991                          1742   10469
# 14                             711                           640   10456
# 15                            1034                           992   11237
# 16                             895                           403   10029
# 17                             938                           915   11237
# 18                             200                           187   11226
# 19                             389                           346   10454
# 20                             462                           391   11221
# 21                             626                           425   10453
# 22                             638                           608   11207
# 23                            1076                          1059   11221
# 24                             383                           347   11219
# 25                             277                           243   11419
# 26                             644                           618   10458
# 27                             205                           193   10038
# 28                             336                           314   10462
# 29                             488                           470   11435
# ...                            ...                           ...     ...
# 87997                          914                           899   10462
# 87998                          259                           192   10001
# 87999                          248                           227   10009
# 88000                          659                           630   10011
# 88001                          207                           188   11220
# 88002                          361                           310   10468
# 88003                          570                           540   11368
# 88004                          204                           178   10029
# 88005                          422                           413   11233
# 88006                          545                           518   11212
# 88007                          549                           525   10016
# 88008                          489                           456   10075
# 88009                          591                           566   10463
# 88010                         2483                          2470   10456
# 88011                          779                           755   10002
# 88012                          469                           449   10458
# 88013                          443                           436   11214
# 88014                          764                           752   10025
# 88015                          513                           443   11362
# 88016                          181                           169   10002
# 88017                          358                           336   10456
# 88018                          463                           454   10466
# 88019                          412                           402   10473
# 88020                          703                           464   11206
# 88021                         1391                          1360   10475
# 88022                          292                           287   10306
# 88023                          437                           373   10027
# 88024                          474                           437   11214
# 88025                         1048                           940   10462
# 88026                          540                           429   11239
#
#        incident_response_min_qy
# 0                         13.28
# 1                          7.40
# 2                         11.72
# 3                          4.70
# 4                          8.22
# 5                         10.55
# 6                          4.40
# 7                          8.73
# 8                          6.48
# 9                         11.60
# 10                        12.68
# 11                        13.60
# 12                        21.22
# 13                        33.18
# 14                        11.85
# 15                        17.23
# 16                        14.92
# 17                        15.63
# 18                         3.33
# 19                         6.48
# 20                         7.70
# 21                        10.43
# 22                        10.63
# 23                        17.93
# 24                         6.38
# 25                         4.62
# 26                        10.73
# 27                         3.42
# 28                         5.60
# 29                         8.13
# ...                         ...
# 87997                     15.23
# 87998                      4.32
# 87999                      4.13
# 88000                     10.98
# 88001                      3.45
# 88002                      6.02
# 88003                      9.50
# 88004                      3.40
# 88005                      7.03
# 88006                      9.08
# 88007                      9.15
# 88008                      8.15
# 88009                      9.85
# 88010                     41.38
# 88011                     12.98
# 88012                      7.82
# 88013                      7.38
# 88014                     12.73
# 88015                      8.55
# 88016                      3.02
# 88017                      5.97
# 88018                      7.72
# 88019                      6.87
# 88020                     11.72
# 88021                     23.18
# 88022                      4.87
# 88023                      7.28
# 88024                      7.90
# 88025                     17.47
# 88026                      9.00
#
# [88027 rows x 13 columns]

# %%
respir_df.to_csv('respir.csv', index=False)

# %% [markdown]
# ### The areas (zipcodes) with more respiratory problems

# %%
results_df.groupby('zipcode').zipcode.count().sort_values(ascending=False).head(20)
# Out:
# zipcode
# 10456    2816
# 11207    2383
# 10457    2256
# 11212    2178
# 10453    2112
# 10458    2049
# 11208    2042
# 11233    1780
# 10467    1779
# 10029    1677
# 10452    1636
# 11226    1627
# 11221    1620
# 10027    1503
# 10460    1491
# 10468    1478
# 10035    1464
# 10459    1444
# 10451    1417
# 11206    1394
# Name: zipcode, dtype: int64

# %%
results_df.groupby('zipcode').zipcode.count().sort_values(ascending=False).head(5).sort_values().plot(kind='barh', color = "lightblue", title="Areas (zipcodes) with more respiratory incidents")

# %%
# Where are these areas?

# %%
type(results_df.incident_response_seconds_qy)
# Out:
# pandas.core.series.Series

# %%
results_df.incident_response_seconds_qy.head()
# Out:
# 0     797
# 1     444
# 2     703
# 3     282
# 4    1422
# Name: incident_response_seconds_qy, dtype: object

# %%
results_df['incident_response_seconds_qy'] = results_df['incident_response_seconds_qy'].astype(float)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
results_df.groupby('zipcode').incident_response_seconds_qy.mean().sort_values(ascending=False).head(5).sort_values()
# Out:
# zipcode
# 10103     888.000000
# 10000     891.500000
# 10119     893.000000
# 10111    1033.000000
# 10154    1781.333333
# Name: incident_response_seconds_qy, dtype: float64

# %%
results_df.groupby('zipcode').incident_response_seconds_qy.mean().sort_values(ascending=False).head(5).sort_values().plot(kind='barh', color="lightblue", title="Avg respiratory response time per zipcode in seconds")
plt.savefig("output-bargraph.pdf", transparent=True)

# %%
# 10154 zipcode, an area in Midtown Manhattan, suffers the longest emergency response time in NYC for respiratory problems

# %%
results_df.groupby('final_call_type').initial_call_type.count().sort_values(ascending=False)
# Out:
# final_call_type
# RESPIR    113578
# Name: initial_call_type, dtype: int64

# %%
results_df
# Out:
#          atom                   borough cad_incident_id citycouncildistrict  \
# 0         NaN                     BRONX       130010001                  18
# 1         NaN                 MANHATTAN       130010013                   2
# 2         NaN                  BROOKLYN       130010091                  40
# 3         NaN                  BROOKLYN       130010105                  35
# 4         NaN                 MANHATTAN       130010172                   3
# 5         NaN                    QUEENS       130010204                  32
# 6         NaN                  BROOKLYN       130010209                  33
# 7         NaN                     BRONX       130010402                  16
# 8         NaN                  BROOKLYN       130010423                  37
# 9         NaN                  BROOKLYN       130010433                  37
# 10        NaN  RICHMOND / STATEN ISLAND       130010452                  49
# 11        NaN                  BROOKLYN       130010460                  37
# 12        NaN                 MANHATTAN       130010511                   8
# 13        NaN                  BROOKLYN       130010571                  39
# 14        NaN                     BRONX       130010868                  15
# 15        NaN                     BRONX       130010932                  17
# 16        NaN                  BROOKLYN       130010977                  35
# 17        NaN                     BRONX       130011009                  12
# 18        NaN                  BROOKLYN       130011013                  36
# 19        NaN                     BRONX       130011141                   8
# 20        NaN                  BROOKLYN       130011270                  36
# 21        NaN                    QUEENS       130011322                  25
# 22        NaN                     BRONX       130011334                  16
# 23        NaN                    QUEENS       130011474                  22
# 24        NaN                  BROOKLYN       130011545                  46
# 25        NaN                  BROOKLYN       130011554                  37
# 26        NaN                 MANHATTAN       130011794                   9
# 27        NaN                 MANHATTAN       130011892                 NaN
# 28        NaN                 MANHATTAN       130011905                   8
# 29        NaN                  BROOKLYN       130011938                  35
# ...       ...                       ...             ...                 ...
# 113548  025BA                 MANHATTAN       172352240                   8
# 113549  081EA                  BROOKLYN       172251035                  36
# 113550  061MC                  BROOKLYN       172080710                  44
# 113551  081CA                  BROOKLYN       161853329                  41
# 113552  073CB                  BROOKLYN       170821502                  41
# 113553  013DA                 MANHATTAN       163532736                   2
# 113554  019GA                 MANHATTAN       171702021                   5
# 113555  050AC                     BRONX       172731867                  11
# 113556  075CD                  BROOKLYN       171353270                  42
# 113557  047BB                     BRONX       170933799                  12
# 113558  044GB                     BRONX       170371323                  16
# 113559  122QR  RICHMOND / STATEN ISLAND       163050143                  51
# 113560  007BD                 MANHATTAN       161941846                   1
# 113561  052HB                     BRONX       172991783                  11
# 113562  062GB                  BROOKLYN       170912534                  47
# 113563  022EB                 MANHATTAN       171602990                   7
# 113564  111GA                    QUEENS       162313193                  19
# 113565  007EB                 MANHATTAN       163160483                   2
# 113566  044HA                     BRONX       172201037                  16
# 113567  047EB                     BRONX       172371641                  12
# 113568  043DA                     BRONX       170340204                  18
# 113569  040CB                     BRONX       171190544                   8
# 113570  090AA                  BROOKLYN       162083946                  36
# 113571  045JA                     BRONX       162810996                  12
# 113572  122FB  RICHMOND / STATEN ISLAND       171931844                  50
# 113573  026DA                 MANHATTAN       161830381                   7
# 113574  062EA                  BROOKLYN       162370618                  47
# 113575  042BA                     BRONX       161964149                  16
# 113576  043JC                     BRONX       161992400                  18
# 113577  075EC                  BROOKLYN       171963823                  42
#
#        communitydistrict communityschooldistrict congressionaldistrict  \
# 0                    209                      12                    15
# 1                    106                       2                    12
# 2                    317                      17                     9
# 3                    309                      17                     9
# 4                    104                       2                    10
# 5                    414                      27                     5
# 6                    301                      14                    12
# 7                    204                       9                    15
# 8                    305                      19                     7
# 9                    305                      19                     8
# 10                   501                      31                    11
# 11                   305                      19                     7
# 12                   111                       4                    13
# 13                   307                      15                     9
# 14                   207                      10                    13
# 15                   202                       8                    15
# 16                   302                      13                     8
# 17                   212                      11                    16
# 18                   303                      16                     8
# 19                   201                       7                    15
# 20                   303                      16                     8
# 21                   404                      24                     6
# 22                   204                       9                    15
# 23                   401                      30                    14
# 24                   318                      22                     8
# 25                   304                      32                     7
# 26                   110                       5                    13
# 27                   NaN                     NaN                   NaN
# 28                   111                       4                    13
# 29                   302                      13                     8
# ...                  ...                     ...                   ...
# 113548               111                       4                    13
# 113549               303                      16                     8
# 113550               312                      21                    10
# 113551               303                      16                     8
# 113552               316                      23                     8
# 113553               106                       2                    12
# 113554               108                       2                    12
# 113555               208                      10                    13
# 113556               305                      19                     8
# 113557               212                      11                    16
# 113558               204                       9                    15
# 113559               502                      31                    11
# 113560               103                       2                    12
# 113561               207                      10                    13
# 113562               311                      21                    11
# 113563               107                       3                    13
# 113564               411                      26                     3
# 113565               103                       1                     7
# 113566               204                       9                    15
# 113567               212                      11                    16
# 113568               209                       8                    15
# 113569               201                       7                    15
# 113570               303                      14                     8
# 113571               210                      11                    16
# 113572               502                      31                    11
# 113573               109                       5                    13
# 113574               311                      21                    10
# 113575               203                       9                    15
# 113576               209                      12                    14
# 113577               305                      19                     8
#
#        dispatch_response_seconds_qy final_call_type final_severity_level_code  \
# 0                               101          RESPIR                         4
# 1                               221          RESPIR                         4
# 2                               152          RESPIR                         4
# 3                                39          RESPIR                         4
# 4                               878          RESPIR                         4
# 5                                23          RESPIR                         4
# 6                                18          RESPIR                         4
# 7                                57          RESPIR                         4
# 8                                11          RESPIR                         4
# 9                                13          RESPIR                         4
# 10                               12          RESPIR                         4
# 11                               34          RESPIR                         4
# 12                              141          RESPIR                         4
# 13                                0          RESPIR                         4
# 14                               41          RESPIR                         4
# 15                              538          RESPIR                         4
# 16                               59          RESPIR                         4
# 17                              249          RESPIR                         4
# 18                              416          RESPIR                         4
# 19                               69          RESPIR                         4
# 20                               55          RESPIR                         4
# 21                               20          RESPIR                         4
# 22                               71          RESPIR                         4
# 23                               24          RESPIR                         4
# 24                               16          RESPIR                         4
# 25                               42          RESPIR                         4
# 26                             2569          RESPIR                         4
# 27                              693          RESPIR                         4
# 28                              492          RESPIR                         4
# 29                              462          RESPIR                         4
# ...                             ...             ...                       ...
# 113548                           26          RESPIR                         4
# 113549                            9          RESPIR                         4
# 113550                           17          RESPIR                         4
# 113551                           19          RESPIR                         4
# 113552                           27          RESPIR                         4
# 113553                           24          RESPIR                         4
# 113554                           33          RESPIR                         4
# 113555                           25          RESPIR                         4
# 113556                           12          RESPIR                         4
# 113557                           17          RESPIR                         4
# 113558                           13          RESPIR                         4
# 113559                           15          RESPIR                         4
# 113560                           24          RESPIR                         4
# 113561                           20          RESPIR                         4
# 113562                            7          RESPIR                         4
# 113563                           12          RESPIR                         4
# 113564                           70          RESPIR                         4
# 113565                           12          RESPIR                         4
# 113566                           22          RESPIR                         4
# 113567                            9          RESPIR                         4
# 113568                           10          RESPIR                         4
# 113569                            9          RESPIR                         4
# 113570                          239          RESPIR                         4
# 113571                           31          RESPIR                         4
# 113572                            5          RESPIR                         4
# 113573                           64          RESPIR                         4
# 113574                           37          RESPIR                         4
# 113575                           59          RESPIR                         4
# 113576                          108          RESPIR                         4
# 113577                          111          RESPIR                         4
#
#          ...   initial_call_type initial_severity_level_code policeprecinct  \
# 0        ...              RESPIR                           4             43
# 1        ...              RESPIR                           4             13
# 2        ...              RESPIR                           4             67
# 3        ...              RESPIR                           4             71
# 4        ...              RESPIR                           4             10
# 5        ...              RESPIR                           4            100
# 6        ...              RESPIR                           4             94
# 7        ...              RESPIR                           4             44
# 8        ...              RESPIR                           4             75
# 9        ...              RESPIR                           4             75
# 10       ...              RESPIR                           4            120
# 11       ...              UNKNOW                           4             75
# 12       ...              RESPIR                           4             23
# 13       ...              RESPIR                           4             72
# 14       ...              RESPIR                           4             52
# 15       ...              RESPIR                           4             41
# 16       ...              RESPIR                           4             88
# 17       ...                SICK                           6             47
# 18       ...              RESPIR                           4             81
# 19       ...              RESPIR                           4             40
# 20       ...              RESPIR                           4             79
# 21       ...              RESPIR                           4            110
# 22       ...              RESPIR                           4             44
# 23       ...              RESPIR                           4            114
# 24       ...              RESPIR                           4             63
# 25       ...              RESPIR                           4             83
# 26       ...                SICK                           6             32
# 27       ...              RESPIR                           4            NaN
# 28       ...              RESPIR                           4             23
# 29       ...              RESPIR                           4             88
# ...      ...                 ...                         ...            ...
# 113548   ...              RESPIR                           4             23
# 113549   ...              RESPIR                           4             81
# 113550   ...              RESPIR                           4             66
# 113551   ...              RESPIR                           4             81
# 113552   ...              RESPIR                           4             73
# 113553   ...              RESPIR                           4             13
# 113554   ...              RESPIR                           4             19
# 113555   ...              RESPIR                           4             50
# 113556   ...              RESPIR                           4             75
# 113557   ...              RESPIR                           4             47
# 113558   ...              RESPIR                           4             44
# 113559   ...              RESPIR                           4            121
# 113560   ...              RESPIR                           4              7
# 113561   ...              RESPIR                           4             52
# 113562   ...              RESPIR                           4             62
# 113563   ...              RESPIR                           4             24
# 113564   ...              RESPIR                           4            111
# 113565   ...              RESPIR                           4              7
# 113566   ...              RESPIR                           4             44
# 113567   ...              RESPIR                           4             47
# 113568   ...              RESPIR                           4             43
# 113569   ...              RESPIR                           4             40
# 113570   ...               OTHER                           6             79
# 113571   ...              RESPIR                           4             45
# 113572   ...              RESPIR                           4            122
# 113573   ...              RESPIR                           4             26
# 113574   ...              INJURY                           5             62
# 113575   ...              RESPIR                           4             42
# 113576   ...              RESPIR                           4             43
# 113577   ...              RESPIR                           4             75
#
#        reopen_indicator special_event_indicator standby_indicator  \
# 0                     N                       N                 N
# 1                     N                       N                 N
# 2                     N                       N                 N
# 3                     N                       N                 N
# 4                     N                       N                 N
# 5                     N                       N                 N
# 6                     N                       N                 N
# 7                     N                       N                 N
# 8                     N                       N                 N
# 9                     N                       N                 N
# 10                    N                       N                 N
# 11                    N                       N                 N
# 12                    N                       N                 N
# 13                    N                       N                 N
# 14                    N                       N                 N
# 15                    N                       N                 N
# 16                    N                       N                 N
# 17                    N                       N                 N
# 18                    N                       N                 N
# 19                    N                       N                 N
# 20                    N                       N                 N
# 21                    N                       N                 N
# 22                    N                       N                 N
# 23                    N                       N                 N
# 24                    N                       N                 N
# 25                    N                       N                 N
# 26                    N                       N                 N
# 27                    N                       N                 N
# 28                    N                       N                 N
# 29                    N                       N                 N
# ...                 ...                     ...               ...
# 113548                N                       N                 N
# 113549                N                       N                 N
# 113550                N                       N                 N
# 113551                N                       N                 N
# 113552                N                       N                 N
# 113553                N                       N                 N
# 113554                N                       N                 N
# 113555                N                       N                 N
# 113556                N                       N                 N
# 113557                N                       N                 N
# 113558                N                       N                 N
# 113559                N                       N                 N
# 113560                N                       N                 N
# 113561                N                       N                 N
# 113562                N                       N                 N
# 113563                N                       N                 N
# 113564                N                       N                 N
# 113565                N                       N                 N
# 113566                N                       N                 N
# 113567                N                       N                 N
# 113568                N                       N                 N
# 113569                N                       N                 N
# 113570                N                       N                 N
# 113571                N                       N                 N
# 113572                N                       N                 N
# 113573                N                       N                 N
# 113574                N                       N                 N
# 113575                N                       N                 N
# 113576                N                       N                 N
# 113577                N                       N                 N
#
#        transfer_indicator valid_dispatch_rspns_time_indc  \
# 0                       N                              Y
# 1                       N                              Y
# 2                       N                              Y
# 3                       N                              Y
# 4                       N                              Y
# 5                       N                              Y
# 6                       N                              Y
# 7                       N                              Y
# 8                       N                              Y
# 9                       N                              Y
# 10                      N                              Y
# 11                      N                              Y
# 12                      N                              Y
# 13                      N                              Y
# 14                      N                              Y
# 15                      N                              Y
# 16                      N                              Y
# 17                      N                              Y
# 18                      N                              Y
# 19                      N                              Y
# 20                      N                              Y
# 21                      N                              Y
# 22                      N                              Y
# 23                      N                              Y
# 24                      N                              Y
# 25                      N                              Y
# 26                      N                              Y
# 27                      N                              Y
# 28                      N                              Y
# 29                      N                              Y
# ...                   ...                            ...
# 113548                  N                              Y
# 113549                  N                              Y
# 113550                  N                              Y
# 113551                  N                              Y
# 113552                  N                              Y
# 113553                  N                              Y
# 113554                  N                              Y
# 113555                  N                              Y
# 113556                  N                              Y
# 113557                  N                              Y
# 113558                  N                              Y
# 113559                  N                              Y
# 113560                  N                              Y
# 113561                  N                              Y
# 113562                  N                              Y
# 113563                  N                              Y
# 113564                  N                              Y
# 113565                  N                              Y
# 113566                  N                              Y
# 113567                  N                              Y
# 113568                  N                              Y
# 113569                  N                              Y
# 113570                  N                              Y
# 113571                  N                              Y
# 113572                  N                              Y
# 113573                  N                              Y
# 113574                  N                              Y
# 113575                  N                              Y
# 113576                  N                              Y
# 113577                  N                              Y
#
#        valid_incident_rspns_time_indc zipcode
# 0                                   Y   10472
# 1                                   Y   10010
# 2                                   Y   11226
# 3                                   Y   11225
# 4                                   Y   10011
# 5                                   Y   11694
# 6                                   Y   11249
# 7                                   Y   10456
# 8                                   Y   11208
# 9                                   Y   11207
# 10                                  Y   10304
# 11                                  Y   11208
# 12                                  Y   10029
# 13                                  Y   11218
# 14                                  Y   10458
# 15                                  Y   10455
# 16                                  Y   11201
# 17                                  Y   10469
# 18                                  Y   11221
# 19                                  Y   10455
# 20                                  Y   11206
# 21                                  Y   11373
# 22                                  Y   10456
# 23                                  Y   11105
# 24                                  Y   11234
# 25                                  Y   11237
# 26                                  N   10037
# 27                                  Y     NaN
# 28                                  Y   10029
# 29                                  Y   11205
# ...                               ...     ...
# 113548                              Y   10029
# 113549                              Y   11233
# 113550                              N   11230
# 113551                              Y   11233
# 113552                              Y   11212
# 113553                              Y   10016
# 113554                              Y   10075
# 113555                              Y   10463
# 113556                              Y   11207
# 113557                              Y   10467
# 113558                              Y   10456
# 113559                              Y   10314
# 113560                              Y   10002
# 113561                              Y   10458
# 113562                              Y   11214
# 113563                              Y   10025
# 113564                              Y   11362
# 113565                              Y   10002
# 113566                              Y   10456
# 113567                              Y   10466
# 113568                              Y   10473
# 113569                              Y   10455
# 113570                              Y   11206
# 113571                              Y   10475
# 113572                              Y   10306
# 113573                              Y   10027
# 113574                              Y   11214
# 113575                              Y   10456
# 113576                              Y   10462
# 113577                              Y   11239
#
# [113578 rows x 32 columns]

# %% [markdown]
# ### CARD

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  "qujCY0ItA3K3bvjptIYdt6Kg1",
                  username="adrianblanco@ucm.es",
                  password="Conocido_91")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results1 = client.get("66ae-7zpy", final_call_type="CARD", limit=200000)

# %%
results1[0]
# Out:
# {'borough': 'BRONX',
#  'cad_incident_id': '130010002',
#  'citycouncildistrict': '8',
#  'communitydistrict': '201',
#  'communityschooldistrict': '7',
#  'congressionaldistrict': '15',
#  'dispatch_response_seconds_qy': '59',
#  'final_call_type': 'CARD',
#  'final_severity_level_code': '3',
#  'first_activation_datetime': '2013-01-01T00:02:08.000',
#  'first_assignment_datetime': '2013-01-01T00:01:18.000',
#  'first_on_scene_datetime': '2013-01-01T00:14:30.000',
#  'held_indicator': 'N',
#  'incident_close_datetime': '2013-01-01T00:55:34.000',
#  'incident_datetime': '2013-01-01T00:00:19.000',
#  'incident_dispatch_area': 'B1',
#  'incident_disposition_code': '93',
#  'incident_response_seconds_qy': '851',
#  'incident_travel_tm_seconds_qy': '792',
#  'initial_call_type': 'CARD',
#  'initial_severity_level_code': '3',
#  'policeprecinct': '40',
#  'reopen_indicator': 'N',
#  'special_event_indicator': 'N',
#  'standby_indicator': 'N',
#  'transfer_indicator': 'N',
#  'valid_dispatch_rspns_time_indc': 'Y',
#  'valid_incident_rspns_time_indc': 'Y',
#  'zipcode': '10454'}

# %%
card_list = []

for row in results1:
    
    rowdict = {}
    
    try:
        
        rowdict['zipcode'] = row['zipcode']
        rowdict['borough'] = row['borough']
        rowdict['incident_datetime'] = row['incident_datetime']
        rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
        rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
        rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
        rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
        rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
        rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
        rowdict['incident_disposition_code'] = row['incident_disposition_code']
        rowdict['final_call_type'] = row['final_call_type']

    #rowdict[''] = row['']

    except:
        
        continue
        
    card_list.append(rowdict)
    
card_df = pd.DataFrame.from_records(card_list)
card_df.head()
# Out:
#                     borough dispatch_response_seconds_qy final_call_type  \
# 0                  BROOKLYN                           19            CARD
# 1  RICHMOND / STATEN ISLAND                           10            CARD
# 2                 MANHATTAN                           93            CARD
# 3                  BROOKLYN                            8            CARD
# 4                    QUEENS                           18            CARD
#
#   first_assignment_datetime first_hosp_arrival_datetime  \
# 0   2013-01-01T00:22:56.000     2013-01-01T01:08:51.000
# 1   2013-01-01T00:29:35.000     2013-01-01T01:17:30.000
# 2   2013-01-01T00:36:22.000     2013-01-01T01:13:06.000
# 3   2013-01-01T00:37:33.000     2013-01-01T01:03:39.000
# 4   2013-01-01T00:39:40.000     2013-01-01T01:22:42.000
#
#    first_on_scene_datetime   first_to_hosp_datetime        incident_datetime  \
# 0  2013-01-01T00:28:54.000  2013-01-01T00:52:03.000  2013-01-01T00:22:37.000
# 1  2013-01-01T00:36:54.000  2013-01-01T01:01:06.000  2013-01-01T00:29:25.000
# 2  2013-01-01T00:43:52.000  2013-01-01T01:08:04.000  2013-01-01T00:34:49.000
# 3  2013-01-01T00:39:14.000  2013-01-01T00:58:19.000  2013-01-01T00:37:25.000
# 4  2013-01-01T00:46:43.000  2013-01-01T01:15:12.000  2013-01-01T00:39:22.000
#
#   incident_disposition_code incident_response_seconds_qy  \
# 0                        82                          377
# 1                        82                          449
# 2                        82                          543
# 3                        82                          109
# 4                        82                          441
#
#   incident_travel_tm_seconds_qy zipcode
# 0                           358   11205
# 1                           439   10314
# 2                           450   10065
# 3                           101   11206
# 4                           423   11420

# %%
card_df['incident_response_seconds_qy'] = card_df['incident_response_seconds_qy'].astype(float)

# %%
card_df.groupby('zipcode').incident_response_seconds_qy.mean().sort_values(ascending=False).head(5).sort_values().plot(kind='barh', color="lightblue", title="Avg respiratory response time per zipcode in seconds")
plt.savefig("output-bargraph2.pdf", transparent=True)

# %%
#drug

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("data.cityofnewyork.us", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofnewyork.us",
                  "qujCY0ItA3K3bvjptIYdt6Kg1",
                  username="adrianblanco@ucm.es",
                  password="Conocido_91")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results1 = client.get("66ae-7zpy", final_call_type="DRUG", limit=200000)

# %%
drug_list = []

for row in results1:
    
    rowdict = {}
    
    try:
        
        rowdict['zipcode'] = row['zipcode']
        rowdict['borough'] = row['borough']
        rowdict['incident_datetime'] = row['incident_datetime']
        rowdict['first_assignment_datetime'] = row['first_assignment_datetime']
        rowdict['incident_travel_tm_seconds_qy'] = row['incident_travel_tm_seconds_qy']
        rowdict['incident_response_seconds_qy'] = row['incident_response_seconds_qy']
        rowdict['first_on_scene_datetime'] = row['first_on_scene_datetime']
        rowdict['first_to_hosp_datetime'] = row['first_to_hosp_datetime']
        rowdict['first_hosp_arrival_datetime'] = row['first_hosp_arrival_datetime']
        rowdict['dispatch_response_seconds_qy'] = row['dispatch_response_seconds_qy']
        rowdict['incident_disposition_code'] = row['incident_disposition_code']
        rowdict['final_call_type'] = row['final_call_type']

    #rowdict[''] = row['']

    except:
        
        continue
        
    drug_list.append(rowdict)
    
drug_df = pd.DataFrame.from_records(drug_list)
drug_df.head()
# Out:
#                     borough dispatch_response_seconds_qy final_call_type  \
# 0  RICHMOND / STATEN ISLAND                           12            DRUG
# 1                 MANHATTAN                           30            DRUG
# 2                  BROOKLYN                           22            DRUG
# 3                 MANHATTAN                         1854            DRUG
# 4                 MANHATTAN                           47            DRUG
#
#   first_assignment_datetime first_hosp_arrival_datetime  \
# 0   2013-01-01T00:02:23.000     2013-01-01T00:38:14.000
# 1   2013-01-01T00:07:58.000     2013-01-01T00:28:40.000
# 2   2013-01-01T00:20:59.000     2013-01-01T00:46:49.000
# 3   2013-01-01T00:51:39.000     2013-01-01T01:42:32.000
# 4   2013-01-01T00:22:55.000     2013-01-01T01:09:58.000
#
#    first_on_scene_datetime   first_to_hosp_datetime        incident_datetime  \
# 0  2013-01-01T00:09:19.000  2013-01-01T00:31:05.000  2013-01-01T00:02:11.000
# 1  2013-01-01T00:11:20.000  2013-01-01T00:25:32.000  2013-01-01T00:07:28.000
# 2  2013-01-01T00:28:07.000  2013-01-01T00:40:23.000  2013-01-01T00:20:37.000
# 3  2013-01-01T00:59:23.000  2013-01-01T01:27:33.000  2013-01-01T00:20:45.000
# 4  2013-01-01T00:28:20.000  2013-01-01T00:57:54.000  2013-01-01T00:22:08.000
#
#   incident_disposition_code incident_response_seconds_qy  \
# 0                        82                          428
# 1                        82                          232
# 2                        82                          450
# 3                        82                         2318
# 4                        82                          372
#
#   incident_travel_tm_seconds_qy zipcode
# 0                           416   10301
# 1                           202   10033
# 2                           428   11203
# 3                           464   10019
# 4                           325   10017

# %%
drug_df['incident_response_seconds_qy'] = drug_df['incident_response_seconds_qy'].astype(float)

# %%
drug_df.groupby('zipcode').incident_response_seconds_qy.mean().sort_values(ascending=False).head(5).sort_values().plot(kind='barh', color="lightblue", title="Avg respiratory response time per zipcode in seconds")
plt.savefig("output-bargraph3.pdf", transparent=True)

# %% [markdown]
# ### TODOS
#
# * Filter columns. Narrow the number of columns
# * Obtain the average response time per emergency
